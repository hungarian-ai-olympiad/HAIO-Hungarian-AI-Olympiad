# %% [markdown]
# © 2026 by Tamás Takács is licensed under CC BY-NC-SA 4.0. To view a copy of this license, visit https://creativecommons.org/licenses/by-nc-sa/4.0/
#
# English translation managed by Tamás Takács. The translation was produced with AI assistance.

# %% [markdown]
# # **Classifier Clone**
#
# <div style="font-size: 14px; color: #6e8192; line-height: 1.5;">
#   <div style="display: flex; align-items: center; gap: 5px; margin-bottom: 5px;">
#     <span style="font-size: 18px; color: #6e8192;">🎯</span>
#     <span>National AI Olympiad Selection Round</span>
#   </div>
#   <div style="display: flex; align-items: center; gap: 5px;">
#     <span style="font-size: 18px; color: #6e8192;">🧠</span>
#     <span>Machine Learning</span>
#   </div>
#   <div style="display: flex; align-items: center; gap: 5px;">
#     <span style="font-size: 18px; color: #6e8192;">🏆</span>
#     <span>100 points</span>
#   </div>
#   <div style="display: flex; align-items: center; gap: 5px;">
#     <span style="font-size: 18px; color: #6e8192;">🗓️</span>
#     <span>24 May 2025</span>
#   </div>
# </div>
#
# **Name:** [WRITE YOUR NAME HERE]
#
# **Contestant ID:** [WRITE YOUR CONTESTANT ID HERE]
#
# <img src="https://drive.google.com/uc?export=view&id=1Gs-32x6jJy1mbQV3j6554gSdwF5r_z3d" alt="klon" style="width:150px;">

# %% [markdown]
# ## **Task Description**:
#
# You are given a pre-trained neural network that was trained for a classification task on a specific *training* dataset. To solve the task, you have at your disposal:
#
# * The trained neural network
# * The training dataset (`X_train`) and labels (`y_train`)
# * A small subset of the test dataset (`X_train_small`) and labels (`y_train_small`)
#
# The goal is to build a machine learning model that is **not neural network based**. The job of this model is to **approximate the output of the trained neural network as closely as possible on the full test dataset**, i.e. to try to imitate its behaviour.
#
# **Requirements for the solution:**
#
# * Choose a machine learning algorithm that is not neural network based.
# * The final model will be evaluated on the full test dataset. Scoring is based on the accuracy metric, according to the following scale (the right end of each interval is open):
#   * 0 - 0.5: 0 points
#   * 0.5 - 0.62: 20 points
#   * 0.62 - 0.66: 30 points
#   * 0.66 - 0.68: 40 points
#   * 0.68 - 0.70: 50 points
#   * 0.70 - 0.71: 70 points
#   * 0.71 - 0.728: 80 points
#   * 0.728 - 0.80: 90 points
#   * 0.80 - 1: 100 points
# * During scoring, the seed set in the first cell will be used. In addition, it is recommended to set a random state for the models as well, since this can influence the results they achieve. During evaluation, every piece of code will be run only once.

# %% [markdown]
# ## **Useful Links**
#
# - [Scikit-Learn - Documentation](https://scikit-learn.org/stable/)
#
# - [Catboost - Documentation](https://catboost.ai/docs/en/concepts/tutorials)
#
# - [LightGBM - Documentation](https://lightgbm.readthedocs.io/en/stable/)
#
# - [XGBoost - Documentation](https://xgboost.readthedocs.io/en/release_3.0.0/)

# %% [markdown]
# ## **Required Imports**

# %%
import torch
import random
import gdown
import numpy as np

seed = 42

torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ## **Downloading the Dataset and the Model**

# %%
# !gdown 1Ib-kv_832voOMhh0wnjTJ-z-9Q9B-t6E # Secret model

# !gdown 1EG6QY3s8X6KKWtVdsswfeOfW3uAzOXU9 # Data

# !gdown 1zf9FUPxVBDrafQUsIirkdZ_rb4a87o3b # Train-Test Split (this is what you must evaluate on)

# %% [markdown]
# ## **Loading the Resources**

# %%
model = torch.jit.load('secret_model.pt')
X_train, X_test_small, y_train, y_test_small = torch.load("data.pt")

# %%
# Your code starts here. Good luck!

# %% [markdown]
# ---
#
# ## 🎉 Congratulations!
#
# You have reached the end of the task set - excellent work!
#
# ---
