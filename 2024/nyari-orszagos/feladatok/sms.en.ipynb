# %% [markdown]
# © 2026 by Tamás Takács is licensed under CC BY-NC-SA 4.0. To view a copy of this license, visit https://creativecommons.org/licenses/by-nc-sa/4.0/
#
# English translation managed by Tamás Takács. The translation was produced with AI assistance.

# %% [markdown]
# # Spam SMS-ek (30 pont)

# %% [markdown]
# **Import the notebook into Colab and work there!**

# %% [markdown]
# **Contestant's name:**

# %% [markdown]
# One day, John Smart woke up to find that more than a thousand text messages had flooded his old Nokia 3310. He would like to find out which text messages he needs to deal with and which ones count as spam.
# Help him decide which text messages qualify as spam!

# %% [markdown]
# ---
# # Preparations
#
# **Guides to the tools needed to solve the task:**
# 1. [Pandas](https://pandas.pydata.org/docs/user_guide/10min.html)
# 2. [Pandas Dataframe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html)
# 3. [Tokenization](https://medium.com/@utkarsh.kant/tokenization-a-complete-guide-3f2dd56c0682)
# 4. [Tokenization, Mapping and Padding](https://medium.com/@lokaregns/preparing-text-data-for-transformers-tokenization-mapping-and-padding-9fbfbce28028)
# 5. [PyTorch Training/Inference](https://pytorch.org/tutorials/beginner/introyt/trainingyt.html)
# 6. [PyTorch Datasets and DataLoaders](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html)
# 7. [Pytorch NN Module](https://pytorch.org/docs/stable/generated/torch.nn.Module.html)

# %% [markdown]
# The **text messages** needed for the solution come from the [UCI SMS Spam Collection](https://archive.ics.uci.edu/dataset/228/sms+spam+collection) dataset.
#
# Alternative source: [Kaggle SMS Spam Collection](https://www.kaggle.com/datasets/uciml/sms-spam-collection-dataset)
#
# ⚠️ **The model weights (`pth` file) are no longer available.** Task 4 (loading the weights) and Task 5 (testing the model) cannot be fully completed without them.

# %%
# Downloading the SMS dataset (UCI SMS Spam Collection)
# The original Google Drive link is no longer available.
# Alternative: download it manually from Kaggle:
# https://www.kaggle.com/datasets/uciml/sms-spam-collection-dataset

# With the Kaggle CLI:
# !pip install -q kaggle
# !kaggle datasets download -d uciml/sms-spam-collection-dataset
# !unzip -qq sms-spam-collection-dataset.zip

# ⚠️ The model weights are no longer available.
# !gdown -qq 1-MtzrY1JqJEfvxuSASobGOYWAoZ3NeGu  # SMS data (not available)
# !gdown -qq 1I7IJZ-ieEXCp-AVmrUzaFXPjLCNNLvKc  # Model weights (not available)

# %% [markdown]
# ## Required Libraries
#
# We have imported a few libraries to get you started, but feel free to use any PyTorch-based tool if you need to. Please note that Keras and TensorFlow are **NOT ALLOWED** for solving this task!

# %%
import torch
import re
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from collections import Counter
from torch.nn.utils.rnn import pad_sequence

# %% [markdown]
# ## Illustrating the SMS Dataset
#
# The code below visualizes the size of the dataset and the first five text messages received.
#
# Every text also has a label indicating whether the given message is **spam** or **legit** (not spam). [Pandas Dataframe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html)

# %%
df = pd.read_csv('./sms.csv')
print("Number of received text messages", len(df))
df.head()

# %% [markdown]
# # Task 1: Exploratory Data Analysis (8 Points)
#
# In the first task we want to perform an initial analysis and data cleaning on the SMS dataset, so that we get to know the messages that arrived on John's phone better. Your tasks are the following:
#
# 1. Count how many unique words (tokens) there are in the dataset! (1 point)
#
# 2. Compute the number of text messages classified into the **spam** and **legit** categories! (1 point)
#
# 3. Clean the dataset using the provided clean_text function! Do not modify the function! (1 point)
#
# 4. Add the cleaned data to the original DataFrame as a new Pandas column! Visualize the updated dataset! (1 point)
#
# [Pandas](https://pandas.pydata.org/docs/user_guide/10min.html)

# %%
def clean_text(text):
    text = re.sub(r'[^\x00-\x7F]+', ' ', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    return text.lower()

def unique_word_count():
    raise NotImplementedError("This function has not been implemented yet.")

def sentiment_count():
    raise NotImplementedError("This function has not been implemented yet.")

# %% [markdown]
# # Task 2: Preparing the data (10 Points)
#
# In the second task we want to build a vocabulary that assigns a numeric value to each unique word. This process is called **tokenization**, and the method above is one of its simplest forms. You may use any library to solve the tasks! Your tasks are the following:
#
# 1. Create your own tokenizer that assigns a unique index to every word! (2 points) [Tokenization](https://medium.com/@utkarsh.kant/tokenization-a-complete-guide-3f2dd56c0682)
# 2. Run the tokenizer on the whole dataset so that every text message gets a numeric sequence representation! (1 point)
# 3. Find the longest text message, then pad all the other messages with empty tokens to match it, so that you get token sequences of equal length! (2 points) [Tokenization, Mapping and Padding](https://medium.com/@lokaregns/preparing-text-data-for-transformers-tokenization-mapping-and-padding-9fbfbce28028)
# 4. Store the labels of the text messages using binary encoding: `[spam = 0, legit = 1]` (1 point)
# 5. Add the resulting token sequences and the binary-encoded SMS labels to the initial Pandas DataFrame (1 point)

# %%
def tokenize():
    raise NotImplementedError("This function has not been implemented yet.")

def build_vocab():
    raise NotImplementedError("This function has not been implemented yet.")

def pad_token_sequences():
    raise NotImplementedError("This function has not been implemented yet.")

def binary_encoding():
    raise NotImplementedError("This function has not been implemented yet.")

# %% [markdown]
# # Task 3: Creating a PyTorch Dataset (3 Points)
#
# For the third task you need to create a PyTorch Dataset that can handle the token sequences and their corresponding binary labels. [PyTorch Datasets and DataLoaders](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html)

# %%
class SMSDataset(Dataset):
    def __init__(self, sequences, labels):
        raise NotImplementedError("This function has not been implemented yet.")

    def __len__(self):
        raise NotImplementedError("This function has not been implemented yet.")

    def __getitem__(self, idx):
        raise NotImplementedError("This function has not been implemented yet.")

# %% [markdown]
# # Task 4: Building the model (5 Points)
#
# Based on the following figure, build the neural network model needed for classifying the text messages! This model will be able to process the tokenized texts and then classify them into the spam and legit categories.
#
# 1. After creating the model, load the weights into it!
#
# <a href="https://ibb.co/F6KF3xC"><img src="https://i.ibb.co/b1PkmWD/net-emb.png" alt="net-emb" border="0"></a>
#
# The `vocab size` is the number of unique tokens (9476 + PAD token = 9477), and `output_dim` is the number of possible classes (`spam`, `legit`). (4 points)
#
# [Pytorch NN Module](https://pytorch.org/docs/stable/generated/torch.nn.Module.html)
#
# 2. Load the model weights into the model you built using the model file named `jános_email_modell.pth`! (1 point) ([Pytorch Loading Weights](https://pytorch.org/tutorials/beginner/basics/saveloadrun_tutorial.html#:~:text=To%20load%20model%20weights%2C%20you,parameters%20using%20load_state_dict()%20method.&text=be%20sure%20to%20call%20model,normalization%20layers%20to%20evaluation%20mode))

# %%
EMBEDDING_DIM = 16

class SMSModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, output_dim):
        super(SMSModel, self).__init__()
        raise NotImplementedError("This function has not been implemented yet.")

    def forward(self, x):
        raise NotImplementedError("This function has not been implemented yet.")


def load_weights():
    raise NotImplementedError("This function has not been implemented yet.")

# %% [markdown]
# # Task 5: Testing the model (4 Points)
#
# At this very moment the following text message has arrived on John's phone:
#
# `Hey, János. I have a crazy hiking opportunity for you in the best place on Earth, the Himalayas. I can be your hiking partner right away, just send me your bank information and personal details, and let's get started.`
#
# 1. Help him decide whether the message he received is spam or not! (2 points)
# 2. Send a message to John: try to write a message that you create with malicious intent (`spam`), but which the model will classify as genuine (`legit`)! (2 points)
#
# [PyTorch Training/Inference](https://pytorch.org/tutorials/beginner/introyt/trainingyt.html)

# %%
def predict():
    raise NotImplementedError("This function has not been implemented yet.")

# %% [markdown]
# ---
# **You have reached the end of the task**. Download the finished Notebook as follows:
# ```
# File → Download → Download .ipynb
# ```
# then upload it to the CMS system **together with the other solutions**, packaged in an archive **(.zip)**.
