# %% [markdown]
# © 2026 by Tamás Takács is licensed under CC BY-NC-SA 4.0. To view a copy of this license, visit https://creativecommons.org/licenses/by-nc-sa/4.0/
#
# English translation managed by Tamás Takács. The translation was produced with AI assistance.

# %% [markdown]
# # Farmer John the Smart (25 points)

# %% [markdown]
# **Import the notebook into Colab and work there!**

# %% [markdown]
# **Contestant's name:**

# %% [markdown]
# Farmer John the Smart decides to take up industrial espionage, but unfortunately he can only afford to enrol in the local retirement home's computer course to train himself as a hacker. Once he feels he has grasped the basics of modern technology, he arranges a friendly drink with the neighbouring farmer and then sneaks into his study. With his patchy knowledge he cannot break into the victim's database, but he does manage to download the profile pictures attached to the animals' records.
#
# Since he found pictures of a huge number of animals, he has hired you to write him a script that aggregates the illegally obtained information and reveals to John the composition of Farmer Frank's livestock. Decide for each image which animal is in it, then total up the number of animals in the last text box!

# %% [markdown]
# ---
# # Preparations
#
# **Guides to the tools needed to solve the task:**
#
# 1. [EfficientNet](https://pytorch.org/hub/nvidia_deeplearningexamples_efficientnet/)
# 2. [PyTorch Datasets and DataLoaders](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html)
# 3. [PyTorch Transforms](https://pytorch.org/vision/main/transforms.html)
# 4. [Pytorch Loading Weights](https://pytorch.org/tutorials/beginner/basics/saveloadrun_tutorial.html#:~:text=To%20load%20model%20weights%2C%20you,parameters%20using%20load_state_dict()%20method.&text=be%20sure%20to%20call%20model,normalization%20layers%20to%20evaluation%20mode)
# 5. [PyTorch Training/Inference](https://pytorch.org/tutorials/beginner/introyt/trainingyt.html)
# 6. [Torch Linear](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)

# %% [markdown]
# ⚠️ **The data is no longer available.** A custom image dataset (állatok.zip) + model weights, custom competition material, lost due to the deletion of the Google Drive.
#
# The original Google Drive links do not work.

# %%
# ⚠️ Data not available (Google Drive deleted)
# @title Downloading the images and the model weights
# !gdown -qq 1R7_GkPvbES1TiTANJVhNVvhKFiRvCF3P
# !gdown -qq 1zP8XVsNLszjNjkCeJOnuIV48C6mWdtYZ
# !unzip -qq állatok.zip -d állatok
# !rm -rf állatok.zip

# %% [markdown]
# ## Required Libraries
#
# We have imported a few libraries to get you started, but feel free to use any PyTorch-based tool if you need to. Please note that Keras and TensorFlow are **NOT ALLOWED** for solving this task!

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision.models as models


from PIL import Image
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from torchvision.models.efficientnet import EfficientNet_B2_Weights

# %% [markdown]
# ### John the Smart found **10** different animals on the farmer's computer, to which the following numeric representations are assigned:

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
classes = {0: 'butterfly',
            1: 'cat',
            2: 'cow',
            3: 'dog',
            4: 'elephant',
            5: 'hen',
            6: 'horse',
            7: 'sheep',
            8: 'spider',
            9: 'squirrel'}

# %% [markdown]
# # Task 1: Initialising the model (8 Points)
#
# In the first task we want to load the classifier model. To do this, import the **EfficientNet B2** model ([EfficientNet](https://pytorch.org/hub/nvidia_deeplearningexamples_efficientnet/)) using PyTorch with pretrained weights!
#
# ```
# EfficientNet_B2_Weights.DEFAULT
# ```
#
#  After loading, freeze the weights of the pretrained model to prevent the model from being updated! Then replace the existing classifier head with a new classifier head as specified in the attached figure:
#
# <a href="https://ibb.co/Bj9931G"><img src="https://i.ibb.co/FJFF3PX/network.png" alt="network" border="0"></a>
#
# The value of ```out``` equals the number of features arriving at the classifier head of the pretrained model. ([Torch Linear](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html), ```in_features```)

# %%
def make_model():
    raise NotImplementedError("This function has not been implemented yet.")

# %% [markdown]
# # Task 2: Loading the weights (1 Point)
#
# Load the model weights into the EfficientNet B2 model using the model file named `jános_modell.pth`! ([Pytorch Loading Weights](https://pytorch.org/tutorials/beginner/basics/saveloadrun_tutorial.html#:~:text=To%20load%20model%20weights%2C%20you,parameters%20using%20load_state_dict()%20method.&text=be%20sure%20to%20call%20model,normalization%20layers%20to%20evaluation%20mode))

# %%
def load_weights():
    raise NotImplementedError("This function has not been implemented yet.")

# %% [markdown]
# # Task 3: Creating a PyTorch Dataset (4 Points)
#
# For the third task you need to create a PyTorch Dataset that can load the images found on the computer. Make sure your Dataset class can also handle image transforms! [PyTorch Dataset](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html)

# %%
class PhotoDataset(Dataset):
    def __init__(self, directory, transform=None):
        raise NotImplementedError("This function has not been implemented yet.")

    def __len__(self):
        raise NotImplementedError("This function has not been implemented yet.")

    def __getitem__(self, idx):
        raise NotImplementedError("This function has not been implemented yet.")

# %% [markdown]
# # Task 4 (2 Points)
#
# John has noticed that the size of the downloaded images is **too large** and the computer cannot open them. Help him scale the images down to a size of 224x224 [PyTorch Transforms](https://pytorch.org/vision/main/transforms.html). John would also like to normalise the images based on the following RGB channel statistics:
#
# `mean=[0.485, 0.456, 0.406]`
#
# `std=[0.229, 0.224, 0.225]`

# %%
def apply_transforms():
    raise NotImplementedError("This function has not been implemented yet.")

# %% [markdown]
# # Task 5 (10 Points)
#
# For the last task, go through all the images found on the computer and run them through the finished model! Count how many animals John found pictures of during his operation, in the **following format**:
#
# ```
# animal_1 = x
# animal_2 = y
# .
# .
# .
# animal_n = z
# ```
# [PyTorch Training/Inference](https://pytorch.org/tutorials/beginner/introyt/trainingyt.html)

# %%
def run_inference()
    raise NotImplementedError("This function has not been implemented yet.")

# %% [markdown]
# ---
# **You have reached the end of the task**. Download the finished Notebook as follows:
# ```
# File → Download → Download .ipynb
# ```
# then upload it, packaged **(.zip)** **together with the other solutions**, to the CMS system.
