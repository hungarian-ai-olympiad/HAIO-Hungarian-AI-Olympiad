# %% [markdown]
# © 2026 by Tamás Takács is licensed under CC BY-NC-SA 4.0. To view a copy of this license, visit https://creativecommons.org/licenses/by-nc-sa/4.0/
#
# English translation managed by Tamás Takács. The translation was produced with AI assistance.

# %% [markdown]
# # Elrejtett kincs (20 pont)

# %% [markdown]
# **Import the notebook into Colab and work there!**

# %% [markdown]
# **Contestant's name:**

# %% [markdown]
# One day, while rummaging around in his attic, John Smart found an old book. The book contains photographs of breathtaking natural wonders. Looking at one of the pictures more closely, he noticed that strange characters were printed on the photograph.
#
# Help John Smart interpret the characters found in the photographs and tell him which geographical coordinate can be read out by combining the data found in the photographs!
#
# **Sample output (incorrect answer, pay attention only to the format):**
#
# Final Coordinate is:
#  N 12° 11,504'
#  E 34° 1,528'

# %% [markdown]
# ---
# # Preparations
#
# **Guides to the tools needed to solve the task:**
#
# 1. [EasyOCR](https://medium.com/@adityamahajan.work/easyocr-a-comprehensive-guide-5ff1cb850168)
# 2. [PyTorch Datasets and DataLoaders](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html)
# 3. [PyTorch Transforms](https://pytorch.org/vision/main/transforms.html)
# 4. [PyTorch Training/Inference](https://pytorch.org/tutorials/beginner/introyt/trainingyt.html)

# %%
# @title Installing Dependencies
# !pip install -qq easyocr
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 23.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 48.6 MB/s eta 0:00:00

# %% [markdown]
# ⚠️ **The data is no longer available.** A custom image dataset (hegyek.zip), custom competition material, was lost when the Google Drive was deleted.
#
# The original Google Drive links do not work.

# %%
# ⚠️ Data not available (Google Drive deleted)
# @title Downloading the Images
# !gdown -qq 1p6ikCp62HoxE0BSHwoO8zhNJC1RbxbzC
# !unzip -qq hegyek.zip -d hegyek
# !rm -rf hegyek.zip

# %% [markdown]
# ## Required Libraries
#
# We have imported a few libraries to get you started, but feel free to use any PyTorch-based tool if you need to. Please note that Keras and TensorFlow are **NOT ALLOWED** for solving this task!

# %%
import os
import easyocr
import torch
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as patches

from PIL import Image

from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets

plt.style.use('ggplot')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Initializing EasyOCR
#
# The Easy OCR package is an optical character recognition tool used to extract textual information from images. We have set up the main package for you. For solving the task, you can find all further usage details, functions and a comprehensive description on the following page: [EasyOCR](https://medium.com/@adityamahajan.work/easyocr-a-comprehensive-guide-5ff1cb850168)

# %%
reader = easyocr.Reader(['en'])

# %% [markdown]
# # Task 1: Creating a PyTorch Dataset (4 Points)
#
# In the first task we want to create a PyTorch Dataset that is able to handle the images on the camera. Your tasks are the following:
#
# 1. Create a PyTorch Dataset based on the given template! [PyTorch Dataset](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html)
#
# 2. Prepare your dataset handler so that it will also be able to handle image transformations later on!

# %%
class MountainDataset(Dataset):
    def __init__(self, directory, transform=None):
        raise NotImplementedError("This function has not been implemented yet.")

    def __len__(self):
        raise NotImplementedError("This function has not been implemented yet.")

    def __getitem__(self, idx):
        raise NotImplementedError("This function has not been implemented yet.")

# %% [markdown]
# # Task 2 (3 Points)
#
# John noticed that the images on the camera **got corrupted** during the hike; every single image was flipped both vertically and horizontally. Your tasks are the following:
#
# 1. Create transformations to correctly restore John's images! [PyTorch Transforms](https://pytorch.org/vision/main/transforms.html)
#
# 2. Instantiate a dataset and configure a DataLoader with a batch size of 1! Make sure that the images are loaded in random order! [PyTorch DataLoader](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html)

# %%
def transform():
    raise NotImplementedError("This function has not been implemented yet.")

# %% [markdown]
# # Task 3 (13 Points)
#
#
# To solve the final task, your job is the following:
#
# 1. Go through all the images found on the camera and, using the OCR (optical character recognition) model, find all the hidden coordinates! Once you have succeeded, print them out in the format given at the beginning of the task!
#
# [PyTorch Training/Inference](https://pytorch.org/tutorials/beginner/introyt/trainingyt.html)

# %%
def run_inference()
    raise NotImplementedError("This function has not been implemented yet.")

# %% [markdown]
# ---
# **You have reached the end of the task**. Download the finished Notebook as follows:
# ```
# File → Download → Download .ipynb
# ```
# then upload it to the CMS system **together with the other solutions**, packaged in a **(.zip)**.
