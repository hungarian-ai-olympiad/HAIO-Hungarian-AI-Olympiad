# %% [markdown]
# © 2026 by Tamás Takács is licensed under CC BY-NC-SA 4.0. To view a copy of this license, visit https://creativecommons.org/licenses/by-nc-sa/4.0/
#
# English translation managed by Tamás Takács. The translation was produced with AI assistance.

# %% [markdown]
# ### **Scientific Task - Neural Playground (20 points)**

# %% [markdown]
# **Import the notebook into Colab and work in it there!**

# %% [markdown]
# **Contestant's name: [WRITE YOUR NAME HERE]**

# %% [markdown]
# **Tensorflow Playground**
#
# TensorFlow Playground is an interactive web interface that lets you experiment with neural networks in a simple, visual way.
#
# Your best friend, John Intelligent, has decided that he too will start studying artificial intelligence. He greatly enjoyed playing with TensorFlow Playground, but sometimes he could not explain what was actually happening.
#
# John Intelligent has collected a few interesting cases for you. Your task will be to explain what phenomenon/process lies behind them. After your explanation, lend your friend a helping hand: give suggestions on how he could solve the problem raised!

# %% [markdown]
# **Question 1** (4 points)
#
# John Intelligent produced the case available at the following link:
#
# [Playground1](https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-gauss&learningRate=3&regularizationRate=0&noise=0&networkShape=4,3&seed=0.98020&showTestData=false&discretize=false&percTrainData=70&x=true&y=true&xTimesY=false&xSquared=true&ySquared=true&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)
#
# Try running the simulation several times!
# John noticed that the Test loss does not decrease.
#
# **What is the explanation for this? (2 points)**
#
# [PLACE FOR YOUR ANSWER]
#
# **How could John Intelligent modify the simulation so that the problem goes away? (2 points)**
#
# Modify only a single parameter! Along with your reasoning, include the Playground link of your solution as well, with the appropriate settings in it.
#
# [PLACE FOR YOUR ANSWER]

# %% [markdown]
# **Question 2** (4 points)
#
# John Intelligent produced the case available at the following link:
#
# [Playground2](https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=2,2&seed=0.94453&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)
#
# Try running the simulation several times!
# John noticed that the Training loss suddenly drops a great deal, and then stagnates.
#
# **What is the explanation for this? (2 points)**
#
# [PLACE FOR YOUR ANSWER]
#
# **How could John Intelligent modify the simulation so that the Training loss does not stagnate? (2 points)**
#
# Along with your reasoning, include the Playground link of your solution as well, with the appropriate settings in it. Try to make a minimal change!
#
# [PLACE FOR YOUR ANSWER]

# %% [markdown]
# **Question 3** (2 points)
#
# John Intelligent produced the case available at the following link:
#
# [Playground3](https://playground.tensorflow.org/#activation=linear&batchSize=10&dataset=spiral&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,4&seed=0.49158&showTestData=false&discretize=false&percTrainData=70&x=true&y=true&xTimesY=false&xSquared=true&ySquared=true&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)
#
# Try running the simulation several times!
# John noticed that increasing the number of neurons in the hidden layers does not make the model any better.
#
# **What is the explanation for this? (2 points)**
#
# [PLACE FOR YOUR ANSWER]

# %% [markdown]
# **Question 4** (4 points)
#
# John Intelligent produced the case available at the following link:
#
# [Playground4](https://playground.tensorflow.org/#activation=linear&batchSize=10&dataset=spiral&regDataset=reg-plane&learningRate=0.001&regularizationRate=0&noise=0&networkShape=4,3&seed=0.83581&showTestData=false&discretize=false&percTrainData=70&x=true&y=true&xTimesY=true&xSquared=true&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)
#
# Try running the simulation several times!
# John is sad, because the simulation's Test loss value does not go below 0.1 (with at most 1000 epochs of training).
#
# **What is the explanation for this? (2 points)**
#
# [PLACE FOR YOUR ANSWER]
#
# **How could John Intelligent modify the simulation so that the problem goes away? (2 points)**
#
# Do not modify the network (the number of hidden layers and neurons)! Experiment only with the other parameters! Try to make a minimal modification.
# Along with your reasoning, include the Playground link of your solution as well, with the appropriate settings in it.
#
# [PLACE FOR YOUR ANSWER]

# %% [markdown]
# **Question 5 (6 points)**
#
# John Intelligent produced the case available at the following link:
#
# [Playground5](https://playground.tensorflow.org/#activation=linear&batchSize=2&dataset=spiral&regDataset=reg-plane&learningRate=0.00001&regularizationRate=0&noise=0&networkShape=7&seed=0.83352&showTestData=false&discretize=false&percTrainData=10&x=false&y=false&xTimesY=true&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)
#
# John is already very tired and has no idea how he could push the Test loss value below 0.1.
# Try to modify the Playground so that it solves the task with a Test loss value of at most 0.1, in at most 1000 epochs!
# Try to make as few changes as possible!
#
# Do not modify the number of hidden layers of the model or the number of neurons in the hidden layer, and do not use regularization either. Keep the Classification type! You may modify the inputs, but keep the X1X2 input type!
#
# Explain every modification below logically, step by step. Apart from those mentioned, you may modify every other parameter, but try to modify as few as possible!
#
# [PLACE FOR YOUR ANSWER]

# %% [markdown]
# ---
# **You have reached the end of the task**. Download the finished Notebook as follows:
# ```
# File → Download → Download .ipynb
# ```
# then upload it to the CMS system **together with the other solutions**, packaged **(.zip)**.
