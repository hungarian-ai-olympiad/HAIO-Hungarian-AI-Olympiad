# %% [markdown]
# ### **Tudományos Feladat - Neural Playground (20 pont)**

# %% [markdown]
# **A notebookot importáld be a Colab rendszerbe, majd abban dolgozz!**

# %% [markdown]
# **Versenyző neve: [ÍRD IDE A NEVED]**

# %% [markdown]
# **Tensorflow Playground**
#
# A TensorFlow Playground egy interaktív webes felület, amely lehetővé teszi számodra, hogy  neurális hálózatokkal kísérletezz egyszerű, vizuális módon.
#
# A legjobb barátod, Intelligens János úgy döntött, hogy ő is elkezdi tanulmányozni a mesterséges intelligencát. Nagyon élvezte a játékot a TensorFlow Playgroundon, de néha nem tudta megmagyarázni azt, hogy mi történik éppen.
#
# Intelligens János összegyűjtött néhány érdekes esetet számondra. A feladatod az lesz, hogy elmagyarázd, milyen jelenség/folyamat áll ezek hátterében. A magyarázad után nyújts segítő kezet barátodnak: adj megoldási javaslatokat arra, hogyan oldhatja meg a felvetett problémát!

# %% [markdown]
# **1. kérdés** (4 pont)
#
# Intelligens János a következő linken elérhető esetet állította elő:
#
# [Playground1](https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-gauss&learningRate=3&regularizationRate=0&noise=0&networkShape=4,3&seed=0.98020&showTestData=false&discretize=false&percTrainData=70&x=true&y=true&xTimesY=false&xSquared=true&ySquared=true&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)
#
# Próbáld meg többször futtatni a szimulációt!
# János észrevette, hogy a Test loss nem csökken.
#
# **Mi a magyarázat erre? (2 pont)**
#
# [VÁLASZ HELYE]
#
# **Hogyan tudná Intelligens János úgy módosítani a szimulációt, hogy a probléma megszűnjön? (2 pont)**
#
# Csak egyetlen paramétert módosíts! Az indoklás mellett szerepeljen a megoldásod Playground linkje is, benne a megfelelő beállításokkal.
#
# [VÁLASZ HELYE]

# %% [markdown]
# **2. kérdés** (4 pont)
#
# Intelligens János a következő linken elérhető esetet állította elő:
#
# [Playground2](https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=2,2&seed=0.94453&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)
#
# Próbáld meg többször futtatni a szimulációt!
# János észrevette, hogy a Training loss hirtelen sokan csökken, majd utána stagnál.
#
# **Mi a magyarázat erre? (2 pont)**
#
# [VÁLASZ HELYE]
#
# **Hogyan tudná Intelligens János úgy módosítani a szimulációt, hogy a Training loss ne stagnáljon? (2 pont)**
#
# Az indoklás mellett szerepeljen a megoldásod Playground linkje is, benne a megfelelő beállításokkal. Próbálj minimális változtatást eszközölni!
#
# [VÁLASZ HELYE]

# %% [markdown]
# **3. kérdés** (2 pont)
#
# Intelligens János a következő linken elérhető esetet állította elő:
#
# [Playground3](https://playground.tensorflow.org/#activation=linear&batchSize=10&dataset=spiral&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,4&seed=0.49158&showTestData=false&discretize=false&percTrainData=70&x=true&y=true&xTimesY=false&xSquared=true&ySquared=true&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)
#
# Próbáld meg többször futtatni a szimulációt!
# János észrevette, hogy a rejtett rétegek neuronjai számának növelésével a modell nem lesz jobb.
#
# **Mi a magyarázat erre? (2 pont)**
#
# [VÁLASZ HELYE]

# %% [markdown]
# **4. kérdés** (4 pont)
#
# Intelligens János a következő linken elérhető esetet állította elő:
#
# [Playground4](https://playground.tensorflow.org/#activation=linear&batchSize=10&dataset=spiral&regDataset=reg-plane&learningRate=0.001&regularizationRate=0&noise=0&networkShape=4,3&seed=0.83581&showTestData=false&discretize=false&percTrainData=70&x=true&y=true&xTimesY=true&xSquared=true&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)
#
# Próbáld meg többször futtatni a szimulációt!
# János szomorú, mert a szimuláció Test loss értéke nem megy 0.1 alá (legfeljebb 1000 epoch tanítással).
#
# **Mi a magyarázat erre? (2 pont)**
#
# [VÁLASZ HELYE]
#
# **Hogyan tudná Intelligens János úgy módosítani a szimulációt, hogy a probléma megszűnjön? (2 pont)**
#
# A hálózatot (rejtett rétegek és neuronok száma) ne módosítsd! Csak az egyéb paraméterekkel kísérletezz! Próbálj minimális módosítást végezni.
# Az indoklás mellett szerepeljen a megoldásod Playground linkje is, benne a megfelelő beállításokkal.
#
# [VÁLASZ HELYE]

# %% [markdown]
# **5. kérdés (6 pont)**
#
# Intelligens János a következő linken elérhető esetet állította elő:
#
# [Playground5](https://playground.tensorflow.org/#activation=linear&batchSize=2&dataset=spiral&regDataset=reg-plane&learningRate=0.00001&regularizationRate=0&noise=0&networkShape=7&seed=0.83352&showTestData=false&discretize=false&percTrainData=10&x=false&y=false&xTimesY=true&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)
#
# János már nagyon elfárdt és nincs ötlete, hogyan szoríthaná be a Test loss értéket 0.1 alá.
# Próbáld úgy módosítani a Playgroundot, hogy a feladatot legfeljebb 0.1-es Test loss értékkel, legfeljebb 1000 epoch alatt megoldja!
# Próbálj minimális számú változtatást eszközölni!
#
# A modell rejtett rétegeinek számát és a rejtett réteg neuronjainak számát ne módosítsd, továbbá regularizációt se használj. Hagyd meg a Classification típust! A bemeneteket módosíthatod, de hagyd meg az X1X2 bemeneti típust!
#
# Minden módosítást logikusan, lépésről-lépésre elmagyarázva fejts ki alább. Az említetteken kívül minden más paramétert módosíthatsz, de igyekezz minimális számút módosítani!
#
# [VÁLASZ HELYE]

# %% [markdown]
# ---
# **A feladat végére értél**. A kész Notebook-ot töltsd le a következő módon:
# ```
# File → Download → Download .ipynb
# ```
# majd a **többi megoldással együtt** töltsd fel a CMS rendszerbe becsomagolva **(.zip)**.
