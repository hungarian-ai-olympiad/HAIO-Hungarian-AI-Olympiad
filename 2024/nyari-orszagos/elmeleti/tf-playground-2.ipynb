# %% [markdown]
# ### **Tudományos Feladat - ChatGPT (30 pont)**

# %% [markdown]
# **A notebookot importáld be a Colab rendszerbe, majd abban dolgozz!**

# %% [markdown]
# **Versenyző neve: [ÍRD IDE A NEVED]**

# %% [markdown]
# **ChatGPT**
#
# A ChatGPT az OpenAI által kifejlesztett mesterséges intelligencia alapú nagy nyelvi modell, amelyet arra terveztek, hogy a kapott bemenet alapján emberszerű választ generáljon. A GPT (Generative Pre-trained Transformer) architektúra egy változatát használja, amelyet úgy finomhangoltak, hogy a témák és feladatok széles skáláján javítsa a megértési és generálási képességeit.
#
# Intelligens János belefáradt abba, hogy a hírek és a napi internetes keresések terén a hagyományos keresőmotorokra hagyatkozzon, ezért a ChatGPT-hez fordult, hogy hatékonyabban tudja megoldani online feladatait.
#
# A következőkben az a feladatod, hogy a ChatGPT hiányoságait megvizsgáld.

# %% [markdown]
# **1. kérdés** (8 pont)
#
# Intelligens János nagyon szereti nézni a Forma 1-es futamokat, viszont a legutóbbiról teljesen lemaradt. Kíváncsi volt, hogy ki nyert, így ezt megkérdezte a ChatGPT-től. A következő választ kapta:
#
# [ChatGPT Válasz](https://drive.google.com/file/d/1JEZmHmNSu4sf0pYWdSzsDVqvqMg5DcYm/view?usp=sharing)
#
# **Mi lehet az oka annak, hogy a ChatGPT nem tud válaszolni a kérdésére? (1 pont)**
#
# [VÁLASZ]
#
# **Van akármilyen mód arra, hogy Intelligens János friss információkat kapjon Forma 1-es eseményekről?** (2 pont)
#
# [VÁLASZ]
#
# **Sorolj fel 5 olyan kérdést, amire a ChatGPT biztos nem tudna válaszolni!** (kérdésenként 1 pont)
#
# [VÁLASZ]

# %% [markdown]
# **2. kérdés** (5 pont)
#
# Intelligens János megelégelte a ChatGPT silány teljesítményét, így manuálisan rákeresett a versenyt összegző Wikipedia oldalra. A szöveg túl hosszú volt számára, így úgy gondolta, ha már a ChatGPT nem tudod friss információval szolgálni neki, odaadja a weblap elérhetőségét, hogy a ChatGPT összegezze neki a történteket. A következő választ kapta:
#
# [ChatGPT Válasz](https://drive.google.com/file/d/1Wn_4Se9GxHkihaWCSWJ4w1OAkCuDw7na/view?usp=sharing)
#
#
# János meglepődött, hiszen ismerte a Forma 1-et és tudta, hogy Pierre Gasly biztos nem nyert. Visszament a modellnek beadott weblapra, ahol megtalálta, hogy a verseny győztese Max Verstappen volt.
#
# **Mi a magyarázat a ChatGPT válaszára?** (3 pont)
#
# [VÁLASZ]
#
# **A ChatGPT tényleg megnyitotta a János által beküldött weboldalt? Válaszodat indokold!** (2 pont)
#
# [VÁLASZ]

# %% [markdown]
# **3. kérdés** (5 pont)
#
# Intelligens János a Forma 1-es bajnokságok alatt, mindig szerette előre számolgatni, hogy nagyjából melyik futamon fognak világbajnokot hirdetni. Most hogy már egy pár futam befejeződött, úgy gondolta, hogy megkérdezi a ChatGPT-t arról, hogy Max Verstappen legkevesebb hány futamból tud világbajnokká válni. A következő választ kapta:
#
# [ChatGPT Válasz](https://drive.google.com/file/d/1_P95O-ghIRV1JXl-81mtxeOsJfm8ZR2C/view?usp=sharing)
#
#
# **Intelligens János hiába volt intelligens, nem értette, hogy a ChatGPT mit számolt ki neki. Segíts Jánosnak megérteni a ChatGPT válaszát! (3 pont)**
#
# [VÁLASZ]
#
# **Mi okozhatja a fenti jelenséget? Miért hibás a ChatGPT formalizmusa? Mi okozza a hibás eredményt? (2 pont)**
#
# [VÁLASZ]

# %% [markdown]
# **4. kérdés** (6 pont)
#
# Intelligens János szereti mesterséges adatokon tesztelni eszmefuttatásait, így úgy gondolta, hogy megkéri a ChatGPT-t, hogy segítsen neki. Egy teszt adatbázisra volt szüksége, ami tartalmaz Forma 1-es versenyzőket és az általuk szerzett pontokat a futamokon. Intelligens János azt is szerette volna kérni a ChatGPT-től, hogy segítsen neki 5 különböző Python kód generálásával, amiből megtudhatja, hogy az egyes pilótnáknak összesítve hány pontja lett a bajnokság végére és azt is, hogy az egyes pilóták hány ponttal maradtak le az első helyezettől.
#
# [ChatGPT Válasz](https://drive.google.com/file/d/1slbdxkmm6Q3x_F7OSHPrKH2SYiHwitoM/view?usp=sharing)
#
#
# **Teszteld le a ChatGPT válaszait, mit veszel észre? (2 pont)**
#
# [VÁLASZ]
#
# **A ChatGPT válaszok közül mely implementációk adnak helyes eredményt? Válaszodat a következő formátumban add meg: `[kód_1, kód_m, ..]` (4 pont)**
#
# [VÁLASZ]

# %% [markdown]
# **5. kérdés (6 pont)**
#
# Intelligens János utolsó megpróbáltatásként tesztelni akarta, hogy a ChatGPT mennyire képes elrejtett szövegek felfedezésére egy hosszabb szövegben. János kimásolta a 2024-es Emilia Romagna Grand Prix Wikipedia összegzését és elhelyezte a szövegben, hogy **Lando Norris a legjobb pilóta**. Mikor visszakérdezte a ChatGPT-től, hogy ki a legjobb pilóta, a következő választ kapta:
#
#
#
# [ChatGPT Válasz](https://drive.google.com/file/d/16KsmxRvQl7bOQyVTxtj7qD2QKkqnAwVg/view?usp=sharing)
#
# **Mi okozhatta, hogy a ChatGPT nem tudott a kérdésre válaszolni? A válaszodat indokold! (2 pont)**
#
# [VÁLASZ]
#
# **Tudnál javaslatot tenni arra, hogy János hová és milyen formában helyezze el a titkos szövegét? Válaszaid indokold! (4 pont)**
#
# [VÁLASZ]

# %% [markdown]
# ---
# **A feladat végére értél**. A kész Notebook-ot töltsd le a következő módon:
# ```
# File → Download → Download .ipynb
# ```
# majd a **többi megoldással együtt** töltsd fel a CMS rendszerbe becsomagolva **(.zip)**.
#
# **Fordíts különös figyelmet arra, hogy a megoldásokat a [VÁLASZ] helyére illeszd be!**
