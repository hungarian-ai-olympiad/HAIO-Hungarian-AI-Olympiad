# %% [markdown]
# © 2026 by Tamás Takács is licensed under CC BY-NC-SA 4.0. To view a copy of this license, visit https://creativecommons.org/licenses/by-nc-sa/4.0/
#
# English translation managed by Tamás Takács. The translation was produced with AI assistance.

# %% [markdown]
# ### **Scientific Task - ChatGPT (30 points)**

# %% [markdown]
# **Import the notebook into Colab and work in it there!**

# %% [markdown]
# **Contestant's name: [WRITE YOUR NAME HERE]**

# %% [markdown]
# **ChatGPT**
#
# ChatGPT is an artificial-intelligence-based large language model developed by OpenAI, designed to generate human-like responses based on the input it receives. It uses a variant of the GPT (Generative Pre-trained Transformer) architecture, fine-tuned to improve its comprehension and generation capabilities across a wide range of topics and tasks.
#
# Smart John had grown tired of relying on traditional search engines for news and everyday internet searches, so he turned to ChatGPT to handle his online tasks more efficiently.
#
# In what follows, your task is to examine ChatGPT's shortcomings.

# %% [markdown]
# **Question 1** (8 points)
#
# Smart John really enjoys watching Formula 1 races, but he missed the most recent one entirely. He was curious about who won, so he asked ChatGPT. He received the following answer:
#
# [ChatGPT Answer](https://drive.google.com/file/d/1JEZmHmNSu4sf0pYWdSzsDVqvqMg5DcYm/view?usp=sharing)
#
# **What might be the reason that ChatGPT cannot answer his question? (1 point)**
#
# [ANSWER]
#
# **Is there any way for Smart John to get up-to-date information about Formula 1 events?** (2 points)
#
# [ANSWER]
#
# **List 5 questions that ChatGPT definitely would not be able to answer!** (1 point per question)
#
# [ANSWER]

# %% [markdown]
# **Question 2** (5 points)
#
# Smart John had had enough of ChatGPT's poor performance, so he manually searched for the Wikipedia page summarizing the race. The text was too long for him, so he figured that since ChatGPT could not provide him with up-to-date information, he would give it the web page's link so that ChatGPT could summarize the events for him. He received the following answer:
#
# [ChatGPT Answer](https://drive.google.com/file/d/1Wn_4Se9GxHkihaWCSWJ4w1OAkCuDw7na/view?usp=sharing)
#
#
# John was surprised, since he knew Formula 1 and knew for certain that Pierre Gasly had not won. He went back to the web page he had given the model, where he found that the winner of the race was Max Verstappen.
#
# **What is the explanation for ChatGPT's answer?** (3 points)
#
# [ANSWER]
#
# **Did ChatGPT really open the web page John submitted? Justify your answer!** (2 points)
#
# [ANSWER]

# %% [markdown]
# **Question 3** (5 points)
#
# During Formula 1 championships, Smart John always liked to work out in advance roughly which race the world champion would be crowned at. Now that a few races had already finished, he decided to ask ChatGPT what is the minimum number of races in which Max Verstappen could become world champion. He received the following answer:
#
# [ChatGPT Answer](https://drive.google.com/file/d/1_P95O-ghIRV1JXl-81mtxeOsJfm8ZR2C/view?usp=sharing)
#
#
# **However smart Smart John was, he did not understand what ChatGPT had calculated for him. Help John understand ChatGPT's answer! (3 points)**
#
# [ANSWER]
#
# **What could cause the phenomenon above? Why is ChatGPT's formalism incorrect? What causes the erroneous result? (2 points)**
#
# [ANSWER]

# %% [markdown]
# **Question 4** (6 points)
#
# Smart John likes to test his lines of reasoning on synthetic data, so he decided to ask ChatGPT for help. He needed a test database containing Formula 1 drivers and the points they had earned at the races. Smart John also wanted to ask ChatGPT to help him by generating 5 different Python codes from which he could find out how many points each driver had in total by the end of the championship, and also by how many points each driver trailed the first-place finisher.
#
# [ChatGPT Answer](https://drive.google.com/file/d/1slbdxkmm6Q3x_F7OSHPrKH2SYiHwitoM/view?usp=sharing)
#
#
# **Test ChatGPT's answers — what do you notice? (2 points)**
#
# [ANSWER]
#
# **Which of the implementations among ChatGPT's answers give the correct result? Give your answer in the following format: `[code_1, code_m, ..]` (4 points)**
#
# [ANSWER]

# %% [markdown]
# **Question 5 (6 points)**
#
# As a final trial, Smart John wanted to test how well ChatGPT can discover hidden text within a longer passage. John copied out the Wikipedia summary of the 2024 Emilia Romagna Grand Prix and placed in the text the statement that **Lando Norris is the best driver**. When he then asked ChatGPT who the best driver is, he received the following answer:
#
#
#
# [ChatGPT Answer](https://drive.google.com/file/d/16KsmxRvQl7bOQyVTxtj7qD2QKkqnAwVg/view?usp=sharing)
#
# **What could have caused ChatGPT to be unable to answer the question? Justify your answer! (2 points)**
#
# [ANSWER]
#
# **Could you make a suggestion as to where and in what form John should place his secret text? Justify your answers! (4 points)**
#
# [ANSWER]

# %% [markdown]
# ---
# **You have reached the end of the task**. Download the finished Notebook as follows:
# ```
# File → Download → Download .ipynb
# ```
# then upload it to the CMS system **together with the other solutions**, packaged in an archive **(.zip)**.
#
# **Pay particular attention to inserting your solutions in place of the [ANSWER] markers!**
